# %%
import pandas as pd

# %%
df = pd.read_csv("Kolkata_weather_data(2017-2022).csv", parse_dates=['Date time'], index_col='Date time')
df.head()
# Out:
#                               Address  Minimum Temperature  \
# Date time
# 2017-01-01  Kolkata,West Bengal,India                 14.0
# 2017-01-02  Kolkata,West Bengal,India                 16.0
# 2017-01-03  Kolkata,West Bengal,India                 16.0
# 2017-01-04  Kolkata,West Bengal,India                 16.0
# 2017-01-05  Kolkata,West Bengal,India                 15.0
#
#             Maximum Temperature  Temperature  Dew Point  Relative Humidity  \
# Date time
# 2017-01-01                 25.3         19.9       16.5              82.47
# 2017-01-02                 26.0         20.6       16.0              76.76
# 2017-01-03                 27.0         21.1       15.6              73.12
# 2017-01-04                 25.0         19.9       14.5              72.57
# 2017-01-05                 25.6         19.6       13.7              71.88
#
#             Heat Index  Wind Speed  Wind Gust  Wind Direction  ...  \
# ...

# %% [markdown]
# ### Checking values of Name

# %%
df['Name'].value_counts()
# Out:
# Name
# Kolkata, WB, India    2191
# Name: count, dtype: int64

# %%
df.drop(['Name'], axis=1, inplace=True)

# %%
print(df['Resolved Address'].value_counts())
print(df['Address'].value_counts())
# Out:
# Resolved Address
# Kolkata, WB, India    2191
# Name: count, dtype: int64
# Address
# Kolkata,West Bengal,India    2191
# Name: count, dtype: int64

# %%
df.drop(['Resolved Address', 'Address'], axis=1, inplace=True)
df.head(10)
# Out:
#             Minimum Temperature  Maximum Temperature  Temperature  Dew Point  \
# Date time
# 2017-01-01                 14.0                 25.3         19.9       16.5
# 2017-01-02                 16.0                 26.0         20.6       16.0
# 2017-01-03                 16.0                 27.0         21.1       15.6
# 2017-01-04                 16.0                 25.0         19.9       14.5
# 2017-01-05                 15.0                 25.6         19.6       13.7
# 2017-01-06                 13.0                 24.6         18.5       11.8
# 2017-01-07                 11.0                 25.3         17.8       11.5
# 2017-01-08                 12.0                 26.2         19.1       12.0
# 2017-01-09                 13.0                 27.0         20.0       12.9
# 2017-01-10                 15.0                 23.2         19.0       12.9
#
#             Relative Humidity  Heat Index  Wind Speed  Wind Gust  \
# Date time
# ...

# %%
df.isnull().sum()
# Out:
# Minimum Temperature       0
# Maximum Temperature       0
# Temperature               0
# Dew Point                 0
# Relative Humidity         0
# Heat Index              340
# Wind Speed                0
# Wind Gust              2100
# Wind Direction            0
# Wind Chill             2178
# Precipitation             0
# Precipitation Cover       0
# Snow Depth              365
# Visibility                0
# Cloud Cover               0
# Sea Level Pressure        1
# Weather Type              1
# Latitude                  0
# Longitude                 0
# Info                   2191
# Conditions                0
# dtype: int64

# %%
df.drop(['Wind Gust', 'Wind Chill', 'Info', 'Snow Depth'], axis=1, inplace=True)
df.columns
# Out:
# Index(['Minimum Temperature', 'Maximum Temperature', 'Temperature',
#        'Dew Point', 'Relative Humidity', 'Heat Index', 'Wind Speed',
#        'Wind Direction', 'Precipitation', 'Precipitation Cover', 'Visibility',
#        'Cloud Cover', 'Sea Level Pressure', 'Weather Type', 'Latitude',
#        'Longitude', 'Conditions'],
#       dtype='object')

# %%
df.head(10)
# Out:
#             Minimum Temperature  Maximum Temperature  Temperature  Dew Point  \
# Date time
# 2017-01-01                 14.0                 25.3         19.9       16.5
# 2017-01-02                 16.0                 26.0         20.6       16.0
# 2017-01-03                 16.0                 27.0         21.1       15.6
# 2017-01-04                 16.0                 25.0         19.9       14.5
# 2017-01-05                 15.0                 25.6         19.6       13.7
# 2017-01-06                 13.0                 24.6         18.5       11.8
# 2017-01-07                 11.0                 25.3         17.8       11.5
# 2017-01-08                 12.0                 26.2         19.1       12.0
# 2017-01-09                 13.0                 27.0         20.0       12.9
# 2017-01-10                 15.0                 23.2         19.0       12.9
#
#             Relative Humidity  Heat Index  Wind Speed  Wind Direction  \
# Date time
# ...

# %%
import mysql.connector
cnx = mysql.connector.connect(user ='root', password='12345', host='localhost', database='kolkata_weather')

# %%
from sqlalchemy import create_engine, text
engine = create_engine('mysql+pymysql://root:12345@localhost/kolkata_weather')

# %%
df.to_sql(name='weather', if_exists = 'replace', con=engine)
# Out:
# 2191

# %%
with engine.connect() as conn:
   query = "ALTER TABLE weather ADD PRIMARY KEY (`Date time`)"
   conn.execute(text(query))

# %%
df.to_csv("Kolkata_weather_data(2017-2022)_processed.csv")
